# %% [markdown]
# # Section 2.1

# %% [markdown]
# ## Load and Unzip Dataset

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1JwIyR97fXRfaciFjm4NLualTzq2XaDTg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown) (3.10.7)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-4.7.1
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1JwIyR97fXRfaciFjm4NLualTzq2XaDTg
# From (redirected): https://drive.google.com/uc?id=1JwIyR97fXRfaciFjm4NLualTzq2XaDTg&confirm=t&uuid=f325b979-e9b0-42ca-b940-63907bd75f9b
# To: /content/archive.zip
# 100% 2.46G/2.46G [01:09<00:00, 35.6MB/s]

# %%
import zipfile
zip_file_path = '/content/archive.zip'
folder_path = '/content/Dataset'
# Extract the zip file to the specified folder
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(folder_path)

# %%
import os
file_path = "/content/archive.zip"
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} has been deleted successfully.")
else:
    print(f"{file_path} does not exist.")
# Out:
# /content/archive.zip has been deleted successfully.

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/Dataset"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")
# Out:
# 3875 (.jpeg) files are in /content/Dataset/chest_xray/train/PNEUMONIA
# 1341 (.jpeg) files are in /content/Dataset/chest_xray/train/NORMAL
# 3875 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/train/PNEUMONIA
# 1341 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/train/NORMAL
# 390 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/test/PNEUMONIA
# 234 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/test/NORMAL
# 8 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/val/PNEUMONIA
# 8 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/val/NORMAL
# 3875 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/train/PNEUMONIA
# 1341 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/train/NORMAL
# 390 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA
# 234 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/test/NORMAL
# 8 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/val/PNEUMONIA
# 8 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/val/NORMAL
# 390 (.jpeg) files are in /content/Dataset/chest_xray/test/PNEUMONIA
# 234 (.jpeg) files are in /content/Dataset/chest_xray/test/NORMAL
# 8 (.jpeg) files are in /content/Dataset/chest_xray/val/PNEUMONIA
# 8 (.jpeg) files are in /content/Dataset/chest_xray/val/NORMAL

# %% [markdown]
# ## Load and Unzip Dataset

# %%
import os

# Define the name of the new folder
new_folder_name = "AllDataPreprocess"

# Define the path where the new folder will be created
parent_folder_path = "/content"

# Check if the new folder already exists
new_folder_path = os.path.join(parent_folder_path, new_folder_name)
if not os.path.exists(new_folder_path):
    # Create the new folder
    os.makedirs(new_folder_path)
    print(f"Created new folder: {new_folder_path}")
else:
    print(f"Folder already exists: {new_folder_path}")

# %%
import os

# Define the name of the new folder
new_folder_name = "AllDataPreprocessNormal"

# Define the path where the new folder will be created
parent_folder_path = "/content"

# Check if the new folder already exists
new_folder_path = os.path.join(parent_folder_path, new_folder_name)
if not os.path.exists(new_folder_path):
    # Create the new folder
    os.makedirs(new_folder_path)
    print(f"Created new folder: {new_folder_path}")
else:
    print(f"Folder already exists: {new_folder_path}")

# %%
import os

# Define the name of the new folder
new_folder_name = "AllDataPreprocessNormalAug"

# Define the path where the new folder will be created
parent_folder_path = "/content"

# Check if the new folder already exists
new_folder_path = os.path.join(parent_folder_path, new_folder_name)
if not os.path.exists(new_folder_path):
    # Create the new folder
    os.makedirs(new_folder_path)
    print(f"Created new folder: {new_folder_path}")
else:
    print(f"Folder already exists: {new_folder_path}")

# %%
import os

# Define the name of the new folder
new_folder_name = "AllDataPreprocessAug"

# Define the path where the new folder will be created
parent_folder_path = "/content"

# Check if the new folder already exists
new_folder_path = os.path.join(parent_folder_path, new_folder_name)
if not os.path.exists(new_folder_path):
    # Create the new folder
    os.makedirs(new_folder_path)
    print(f"Created new folder: {new_folder_path}")
else:
    print(f"Folder already exists: {new_folder_path}")

# %%
import os

# Define the name of the new folder
new_folder_name = "FinalDataset"

# Define the path where the new folder will be created
parent_folder_path = "/content"

# Check if the new folder already exists
new_folder_path = os.path.join(parent_folder_path, new_folder_name)
if not os.path.exists(new_folder_path):
    # Create the new folder
    os.makedirs(new_folder_path)
    print(f"Created new folder: {new_folder_path}")
else:
    print(f"Folder already exists: {new_folder_path}")

# %%
import os

# Define the name of the new folder
new_folder_name = "FinalDatasetNormal"

# Define the path where the new folder will be created
parent_folder_path = "/content"

# Check if the new folder already exists
new_folder_path = os.path.join(parent_folder_path, new_folder_name)
if not os.path.exists(new_folder_path):
    # Create the new folder
    os.makedirs(new_folder_path)
    print(f"Created new folder: {new_folder_path}")
else:
    print(f"Folder already exists: {new_folder_path}")

# %% [markdown]
# ### Prepare Data

# %%
import os
import shutil
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets.folder import default_loader

# Set the path to your input folder here
input_folder_path = "/content/Dataset/chest_xray/chest_xray"

# Define the classes in your dataset
classes = ["NORMAL", "PNEUMONIA"]

# Define the path to the output folder where you want to save the combined data
output_folder_path = os.path.join(input_folder_path, "AllData")

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the train, test, and val folders
for split in ["train", "test", "val"]:
    split_folder_path = os.path.join(input_folder_path, split)

    # Loop through the NORMAL and PNEUMONIA folders in each split folder
    for class_name in classes:
        class_folder_path = os.path.join(split_folder_path, class_name)

        # Loop through the image files in each class folder and copy them to the output folder
        for file_name in os.listdir(class_folder_path):
            if file_name.endswith(".jpeg"):
                src_path = os.path.join(class_folder_path, file_name)
                dst_path = os.path.join(output_folder_path, class_name, file_name)

                # Create the class folder in the output folder if it doesn't exist
                if not os.path.exists(os.path.join(output_folder_path, class_name)):
                    os.makedirs(os.path.join(output_folder_path, class_name))

                # Copy the image file to the output folder
                shutil.copyfile(src_path, dst_path)

# Define a custom PyTorch dataset to load the combined data
class CustomDataset(Dataset):
    def __init__(self, root, classes, transform=None, loader=default_loader):
        self.root = root
        self.classes = classes
        self.transform = transform
        self.loader = loader
        self.samples = []

        # Loop through the NORMAL and PNEUMONIA classes and their respective image folders in the output folder
        for class_name in classes:
            class_folder_path = os.path.join(root, class_name)
            for file_name in os.listdir(class_folder_path):
                if file_name.endswith(".jpeg"):
                    self.samples.append((os.path.join(class_folder_path, file_name), classes.index(class_name)))

    def __getitem__(self, index):
        path, target = self.samples[index]
        sample = self.loader(path)
        if self.transform is not None:
            sample = self.transform(sample)
        return sample, target

    def __len__(self):
        return len(self.samples)

# Load the combined data using the custom PyTorch dataset
dataset = CustomDataset(output_folder_path, classes)

# Use the PyTorch DataLoader to create batches of data for training/testing
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/Dataset/chest_xray/chest_xray/AllData"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")

# %% [markdown]
# ### Just Preprocess

# %%
import os
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Define the path to the input and output folders
input_folder_path = "/content/Dataset/chest_xray/chest_xray/AllData"
output_folder_path = "/content/AllDataPreprocess"

# Define the transformation pipeline to apply to the images
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# Load the data from the input folder using the ImageFolder dataset
data = ImageFolder(input_folder_path, transform=transform)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the NORMAL and PNEUMONIA classes and their respective image folders in the input folder
for class_name in data.classes:
    class_folder_path = os.path.join(output_folder_path, class_name)
    if not os.path.exists(class_folder_path):
        os.makedirs(class_folder_path)

    # Loop through the images in the class folder, apply the transformation pipeline, and save the new images to the output folder
    for i in range(len(data)):
        if data.targets[i] == data.class_to_idx[class_name]:
            image, _ = data[i]
            file_name = data.samples[i][0].split("/")[-1]
            output_path = os.path.join(class_folder_path, file_name)
            torchvision.utils.save_image(image, output_path)

# %%
import os
import numpy as np
import torch
import torchvision.transforms as transforms
from PIL import Image

# Define the path to the folder containing the images
folder_path = "/content/AllDataPreprocess"

# Define the transforms to be applied to each image
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# Define the accumulator variables for the mean and standard deviation
normal_images = []
pneumonia_images = []

# Loop through all files in the folder
for folder_name in ["NORMAL", "PNEUMONIA"]:
    folder = os.path.join(folder_path, folder_name)
    for file_name in os.listdir(folder):
        # Check if the file is an image (JPEG or PNG)
        if file_name.endswith(".jpg") or file_name.endswith(".jpeg") or file_name.endswith(".png"):
            # Open the image file and apply the transforms
            image_path = os.path.join(folder, file_name)
            image = Image.open(image_path)
            image = transform(image)

            # Add the image to the corresponding accumulator variable
            if folder_name == "NORMAL":
                normal_images.append(image)
            else:
                pneumonia_images.append(image)

# Concatenate all images and calculate the mean and standard deviation
normal_images = torch.stack(normal_images)
pneumonia_images = torch.stack(pneumonia_images)
all_images = torch.cat([normal_images, pneumonia_images], dim=0)
mean = torch.mean(all_images, dim=(0, 2, 3))
std = torch.std(all_images, dim=(0, 2, 3))

# Output the mean and standard deviation
print(f"mean={mean.tolist()}, std={std.tolist()}")
# Out:
# mean=[0.48158150911331177, 0.48158150911331177, 0.48158150911331177], std=[0.23505905270576477, 0.23505905270576477, 0.23505905270576477]

# %% [markdown]
# ### Preprocess + Normal

# %%
import os
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Define the path to the input and output folders
input_folder_path = "/content/AllDataPreprocess"
output_folder_path = "/content/AllDataPreprocessNormal"

# Define the transformation pipeline to apply to the images
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4815806746482849, 0.4815806746482849, 0.4815806746482849], std=[0.23505905270576477, 0.23505905270576477, 0.23505905270576477])
])

# Load the data from the input folder using the ImageFolder dataset
data = ImageFolder(input_folder_path, transform=transform)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the NORMAL and PNEUMONIA classes and their respective image folders in the input folder
for class_name in data.classes:
    class_folder_path = os.path.join(output_folder_path, class_name)
    if not os.path.exists(class_folder_path):
        os.makedirs(class_folder_path)

    # Loop through the images in the class folder, apply the transformation pipeline, and save the new images to the output folder
    for i in range(len(data)):
        if data.targets[i] == data.class_to_idx[class_name]:
            image, _ = data[i]
            file_name = data.samples[i][0].split("/")[-1]
            output_path = os.path.join(class_folder_path, file_name)
            torchvision.utils.save_image(image, output_path)

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/AllDataPreprocessNormal"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")

# %% [markdown]
# ### Preprocess + Normal + AUG

# %%
import os
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Define the path to the input and output folders
input_folder_path = "/content/Dataset/chest_xray/chest_xray/AllData"
output_folder_path = "/content/AllDataPreprocessNormalAug"

# Define the transformation pipeline to apply to the images
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomAffine(degrees=30, shear=0.2, scale=(0.8, 1.2), translate=(0.2, 0.2)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0/255, 1.0/255, 1.0/255])
    transforms.Normalize(mean=[0.4815806746482849, 0.4815806746482849, 0.4815806746482849], std=[0.23505905270576477, 0.23505905270576477, 0.23505905270576477])
])

# Load the data from the input folder using the ImageFolder dataset
data = ImageFolder(input_folder_path, transform=transform)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the NORMAL and PNEUMONIA classes and their respective image folders in the input folder
for class_name in data.classes:
    class_folder_path = os.path.join(output_folder_path, class_name)
    if not os.path.exists(class_folder_path):
        os.makedirs(class_folder_path)

    # Loop through the images in the class folder, apply the transformation pipeline, and save the new images to the output folder
    for i in range(len(data)):
        if data.targets[i] == data.class_to_idx[class_name]:
            image, _ = data[i]
            file_name = data.samples[i][0].split("/")[-1]
            output_path = os.path.join(class_folder_path, file_name)
            torchvision.utils.save_image(image, output_path)

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/AllDataPreprocessNormalAug"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")
# Out:
# 1583 (.jpeg) files are in /content/AllDataPreprocessNormalAug/NORMAL
# 4273 (.jpeg) files are in /content/AllDataPreprocessNormalAug/PNEUMONIA

# %% [markdown]
# ### Preprocess + AUG

# %%
import os
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Define the path to the input and output folders
input_folder_path = "/content/Dataset/chest_xray/chest_xray/AllData"
output_folder_path = "/content/AllDataPreprocessAug"

# Define the transformation pipeline to apply to the images
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomAffine(degrees=30, shear=0.2, scale=(0.8, 1.2), translate=(0.2, 0.2)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # transforms.Normalize(mean=[0.4815806746482849, 0.4815806746482849, 0.4815806746482849], std=[0.23505905270576477, 0.23505905270576477, 0.23505905270576477])
])

# Load the data from the input folder using the ImageFolder dataset
data = ImageFolder(input_folder_path, transform=transform)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the NORMAL and PNEUMONIA classes and their respective image folders in the input folder
for class_name in data.classes:
    class_folder_path = os.path.join(output_folder_path, class_name)
    if not os.path.exists(class_folder_path):
        os.makedirs(class_folder_path)

    # Loop through the images in the class folder, apply the transformation pipeline, and save the new images to the output folder
    for i in range(len(data)):
        if data.targets[i] == data.class_to_idx[class_name]:
            image, _ = data[i]
            file_name = data.samples[i][0].split("/")[-1]
            output_path = os.path.join(class_folder_path, file_name)
            torchvision.utils.save_image(image, output_path)

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/AllDataPreprocessAug"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")

# %% [markdown]
# ### Merge and make Final Dataset

# %%
import shutil

# replace `folder_to_delete` with the name of the folder you want to delete
shutil.rmtree("/content/FinalDatasetTVT")

# %%
import os
import shutil

# Path to the new folder
new_folder_path = "/content/FinalDataset"

# Path to the first and second folders
first_folder_path = '/content/AllDataPreprocess'
second_folder_path = '/content/AllDataPreprocessAug'

# Create the new subfolders
os.makedirs(os.path.join(new_folder_path, "NORMAL"))
os.makedirs(os.path.join(new_folder_path, "PNEUMONIA"))

# Copy the files from the first folder
for filename in os.listdir(os.path.join(first_folder_path, "NORMAL")):
    new_filename = filename[:-5] + "_1" + filename[-5:]
    shutil.copy(os.path.join(first_folder_path, "NORMAL", filename), 
                os.path.join(new_folder_path, "NORMAL", new_filename))
for filename in os.listdir(os.path.join(first_folder_path, "PNEUMONIA")):
    new_filename = filename[:-5] + "_1" + filename[-5:]
    shutil.copy(os.path.join(first_folder_path, "PNEUMONIA", filename), 
                os.path.join(new_folder_path, "PNEUMONIA", new_filename))

# Copy the files from the second folder
for filename in os.listdir(os.path.join(second_folder_path, "NORMAL")):
    new_filename = filename[:-5] + "_2" + filename[-5:]
    shutil.copy(os.path.join(second_folder_path, "NORMAL", filename), 
                os.path.join(new_folder_path, "NORMAL", new_filename))
for filename in os.listdir(os.path.join(second_folder_path, "PNEUMONIA")):
    new_filename = filename[:-5] + "_2" + filename[-5:]
    shutil.copy(os.path.join(second_folder_path, "PNEUMONIA", filename), 
                os.path.join(new_folder_path, "PNEUMONIA", new_filename))

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/FinalDataset"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")

# %%
import os
import shutil

# Path to the new folder
new_folder_path = "/content/FinalDatasetNormal"

# Path to the first and second folders
first_folder_path = '/content/AllDataPreprocessNormal'
second_folder_path = '/content/AllDataPreprocessNormalAug'

# Create the new subfolders
os.makedirs(os.path.join(new_folder_path, "NORMAL"))
os.makedirs(os.path.join(new_folder_path, "PNEUMONIA"))

# Copy the files from the first folder
for filename in os.listdir(os.path.join(first_folder_path, "NORMAL")):
    new_filename = filename[:-5] + "_1" + filename[-5:]
    shutil.copy(os.path.join(first_folder_path, "NORMAL", filename), 
                os.path.join(new_folder_path, "NORMAL", new_filename))
for filename in os.listdir(os.path.join(first_folder_path, "PNEUMONIA")):
    new_filename = filename[:-5] + "_1" + filename[-5:]
    shutil.copy(os.path.join(first_folder_path, "PNEUMONIA", filename), 
                os.path.join(new_folder_path, "PNEUMONIA", new_filename))

# Copy the files from the second folder
for filename in os.listdir(os.path.join(second_folder_path, "NORMAL")):
    new_filename = filename[:-5] + "_2" + filename[-5:]
    shutil.copy(os.path.join(second_folder_path, "NORMAL", filename), 
                os.path.join(new_folder_path, "NORMAL", new_filename))
for filename in os.listdir(os.path.join(second_folder_path, "PNEUMONIA")):
    new_filename = filename[:-5] + "_2" + filename[-5:]
    shutil.copy(os.path.join(second_folder_path, "PNEUMONIA", filename), 
                os.path.join(new_folder_path, "PNEUMONIA", new_filename))

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/FinalDatasetNormal"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")
# Out:
# 3166 (.jpeg) files are in /content/FinalDatasetNormal/NORMAL
# 8546 (.jpeg) files are in /content/FinalDatasetNormal/PNEUMONIA

# %% [markdown]
# ### Train,Valid,Test...

# %%
import os
import shutil
import random

# Set the path to the "FinalDataset" folder
data_dir = "/content/FinalDataset"

# Set the path to the output directory
output_dir = "/content/FinalDatasetTVT"

# Set the train/validation/test split ratios
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

# Create the output directories
os.makedirs(os.path.join(output_dir, "train", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "train", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "PNEUMONIA"), exist_ok=True)

# Get the list of image files in each class folder
normal_files = os.listdir(os.path.join(data_dir, "NORMAL"))
pneumonia_files = os.listdir(os.path.join(data_dir, "PNEUMONIA"))

# Shuffle the lists to randomize the order
random.shuffle(normal_files)
random.shuffle(pneumonia_files)

# Calculate the number of images for each split
num_normal = len(normal_files)
num_pneumonia = len(pneumonia_files)
num_train_normal = int(num_normal * train_ratio)
num_train_pneumonia = int(num_pneumonia * train_ratio)
num_val_normal = int(num_normal * val_ratio)
num_val_pneumonia = int(num_pneumonia * val_ratio)
num_test_normal = int(num_normal * test_ratio)
num_test_pneumonia = int(num_pneumonia * test_ratio)

# Copy the image files to the output directories for each split
for i, file in enumerate(normal_files):
    if i < num_train_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "train", "NORMAL"))
    elif i < num_train_normal + num_val_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "val", "NORMAL"))
    else:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "test", "NORMAL"))
for i, file in enumerate(pneumonia_files):
    if i < num_train_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "train", "PNEUMONIA"))
    elif i < num_train_pneumonia + num_val_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "val", "PNEUMONIA"))
    else:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "test", "PNEUMONIA"))

# %%
import os
import shutil
import random

# Set the path to the "FinalDataset" folder
data_dir = "/content/FinalDatasetNormal"

# Set the path to the output directory
output_dir = "/content/FinalDatasetNormalTVT"

# Set the train/validation/test split ratios
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

# Create the output directories
os.makedirs(os.path.join(output_dir, "train", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "train", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "PNEUMONIA"), exist_ok=True)

# Get the list of image files in each class folder
normal_files = os.listdir(os.path.join(data_dir, "NORMAL"))
pneumonia_files = os.listdir(os.path.join(data_dir, "PNEUMONIA"))

# Shuffle the lists to randomize the order
random.shuffle(normal_files)
random.shuffle(pneumonia_files)

# Calculate the number of images for each split
num_normal = len(normal_files)
num_pneumonia = len(pneumonia_files)
num_train_normal = int(num_normal * train_ratio)
num_train_pneumonia = int(num_pneumonia * train_ratio)
num_val_normal = int(num_normal * val_ratio)
num_val_pneumonia = int(num_pneumonia * val_ratio)
num_test_normal = int(num_normal * test_ratio)
num_test_pneumonia = int(num_pneumonia * test_ratio)

# Copy the image files to the output directories for each split
for i, file in enumerate(normal_files):
    if i < num_train_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "train", "NORMAL"))
    elif i < num_train_normal + num_val_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "val", "NORMAL"))
    else:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "test", "NORMAL"))
for i, file in enumerate(pneumonia_files):
    if i < num_train_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "train", "PNEUMONIA"))
    elif i < num_train_pneumonia + num_val_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "val", "PNEUMONIA"))
    else:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "test", "PNEUMONIA"))

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/FinalDatasetNormalTVT"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")
# Out:
# 1709 (.jpeg) files are in /content/FinalDatasetNormalTVT/val/PNEUMONIA
# 1710 (.jpeg) files are in /content/FinalDatasetNormalTVT/test/PNEUMONIA
# 5127 (.jpeg) files are in /content/FinalDatasetNormalTVT/train/PNEUMONIA
# 1709 (.jpeg) files are in /content/FinalDatasetNormalTVT/val/PNEUMONIA
# 1710 (.jpeg) files are in /content/FinalDatasetNormalTVT/test/PNEUMONIA
# 5127 (.jpeg) files are in /content/FinalDatasetNormalTVT/train/PNEUMONIA

# %% [markdown]
# # Section 2.2

# %% [markdown]
# ## Pre

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1JwIyR97fXRfaciFjm4NLualTzq2XaDTg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown) (3.10.7)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-4.7.1
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1JwIyR97fXRfaciFjm4NLualTzq2XaDTg
# From (redirected): https://drive.google.com/uc?id=1JwIyR97fXRfaciFjm4NLualTzq2XaDTg&confirm=t&uuid=3d884393-3158-4bf4-8f3b-5a7d1e9b19bc
# To: /content/archive.zip
# 100% 2.46G/2.46G [00:47<00:00, 51.7MB/s]

# %%
import zipfile
zip_file_path = '/content/archive.zip'
folder_path = '/content/Dataset'
# Extract the zip file to the specified folder
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(folder_path)

# %%
import os
file_path = "/content/archive.zip"
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} has been deleted successfully.")
else:
    print(f"{file_path} does not exist.")
# Out:
# /content/archive.zip has been deleted successfully.

# %%
import os

# Define the path to the parent folder
parent_folder_path = "/content/Dataset"

# Recursively iterate through all subfolders and files in the parent folder
for dirpath, dirnames, filenames in os.walk(parent_folder_path):
    # Get the number of JPEG files in the current directory
    jpeg_count = sum(1 for filename in filenames if filename.lower().endswith('.jpeg'))
    
    # Print out the results for the current directory
    if jpeg_count > 0:
        # Get the relative path to the current directory
        relative_path = os.path.relpath(dirpath, parent_folder_path)
        
        # Print out the results
        print(f"{jpeg_count} (.jpeg) files are in {os.path.join(parent_folder_path, relative_path)}")
# Out:
# 1341 (.jpeg) files are in /content/Dataset/chest_xray/train/NORMAL
# 3875 (.jpeg) files are in /content/Dataset/chest_xray/train/PNEUMONIA
# 1341 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/train/NORMAL
# 3875 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/train/PNEUMONIA
# 8 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/val/NORMAL
# 8 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/val/PNEUMONIA
# 234 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/test/NORMAL
# 390 (.jpeg) files are in /content/Dataset/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA
# 1341 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/train/NORMAL
# 3875 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/train/PNEUMONIA
# 8 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/val/NORMAL
# 8 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/val/PNEUMONIA
# 234 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/test/NORMAL
# 390 (.jpeg) files are in /content/Dataset/chest_xray/chest_xray/test/PNEUMONIA
# 8 (.jpeg) files are in /content/Dataset/chest_xray/val/NORMAL
# 8 (.jpeg) files are in /content/Dataset/chest_xray/val/PNEUMONIA
# 234 (.jpeg) files are in /content/Dataset/chest_xray/test/NORMAL
# 390 (.jpeg) files are in /content/Dataset/chest_xray/test/PNEUMONIA

# %%
import os
import shutil
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets.folder import default_loader

# Set the path to your input folder here
input_folder_path = "/content/Dataset/chest_xray/chest_xray"

# Define the classes in your dataset
classes = ["NORMAL", "PNEUMONIA"]

# Define the path to the output folder where you want to save the combined data
output_folder_path = os.path.join(input_folder_path, "AllData")

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the train, test, and val folders
for split in ["train", "test", "val"]:
    split_folder_path = os.path.join(input_folder_path, split)

    # Loop through the NORMAL and PNEUMONIA folders in each split folder
    for class_name in classes:
        class_folder_path = os.path.join(split_folder_path, class_name)

        # Loop through the image files in each class folder and copy them to the output folder
        for file_name in os.listdir(class_folder_path):
            if file_name.endswith(".jpeg"):
                src_path = os.path.join(class_folder_path, file_name)
                dst_path = os.path.join(output_folder_path, class_name, file_name)

                # Create the class folder in the output folder if it doesn't exist
                if not os.path.exists(os.path.join(output_folder_path, class_name)):
                    os.makedirs(os.path.join(output_folder_path, class_name))

                # Copy the image file to the output folder
                shutil.copyfile(src_path, dst_path)

# Define a custom PyTorch dataset to load the combined data
class CustomDataset(Dataset):
    def __init__(self, root, classes, transform=None, loader=default_loader):
        self.root = root
        self.classes = classes
        self.transform = transform
        self.loader = loader
        self.samples = []

        # Loop through the NORMAL and PNEUMONIA classes and their respective image folders in the output folder
        for class_name in classes:
            class_folder_path = os.path.join(root, class_name)
            for file_name in os.listdir(class_folder_path):
                if file_name.endswith(".jpeg"):
                    self.samples.append((os.path.join(class_folder_path, file_name), classes.index(class_name)))

    def __getitem__(self, index):
        path, target = self.samples[index]
        sample = self.loader(path)
        if self.transform is not None:
            sample = self.transform(sample)
        return sample, target

    def __len__(self):
        return len(self.samples)

# Load the combined data using the custom PyTorch dataset
dataset = CustomDataset(output_folder_path, classes)

# Use the PyTorch DataLoader to create batches of data for training/testing
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import os
import shutil
import random

# Set the path to the "FinalDataset" folder
data_dir = "/content/Dataset/chest_xray/chest_xray/AllData"

# Set the path to the output directory
output_dir = "/content/FinalDatasetTVT2"

# Set the train/validation/test split ratios
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

# Create the output directories
os.makedirs(os.path.join(output_dir, "train", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "train", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "PNEUMONIA"), exist_ok=True)

# Get the list of image files in each class folder
normal_files = os.listdir(os.path.join(data_dir, "NORMAL"))
pneumonia_files = os.listdir(os.path.join(data_dir, "PNEUMONIA"))

# Shuffle the lists to randomize the order
random.shuffle(normal_files)
random.shuffle(pneumonia_files)

# Calculate the number of images for each split
num_normal = len(normal_files)
num_pneumonia = len(pneumonia_files)
num_train_normal = int(num_normal * train_ratio)
num_train_pneumonia = int(num_pneumonia * train_ratio)
num_val_normal = int(num_normal * val_ratio)
num_val_pneumonia = int(num_pneumonia * val_ratio)
num_test_normal = int(num_normal * test_ratio)
num_test_pneumonia = int(num_pneumonia * test_ratio)

# Copy the image files to the output directories for each split
for i, file in enumerate(normal_files):
    if i < num_train_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "train", "NORMAL"))
    elif i < num_train_normal + num_val_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "val", "NORMAL"))
    else:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "test", "NORMAL"))
for i, file in enumerate(pneumonia_files):
    if i < num_train_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "train", "PNEUMONIA"))
    elif i < num_train_pneumonia + num_val_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "val", "PNEUMONIA"))
    else:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "test", "PNEUMONIA"))

# %%
import os
import shutil
import random

# Set the path to the "FinalDataset" folder
data_dir = "/content/Dataset/chest_xray/chest_xray/AllData"

# Set the path to the output directory
output_dir = "/content/FinalDatasetTVT4"

# Set the train/validation/test split ratios
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

# Create the output directories
os.makedirs(os.path.join(output_dir, "train", "0"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "train", "1"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "0"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "1"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "0"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "1"), exist_ok=True)

# Get the list of image files in each class folder
normal_files = os.listdir(os.path.join(data_dir, "NORMAL"))
pneumonia_files = os.listdir(os.path.join(data_dir, "PNEUMONIA"))

# Shuffle the lists to randomize the order
random.shuffle(normal_files)
random.shuffle(pneumonia_files)

# Calculate the number of images for each split
num_normal = len(normal_files)
num_pneumonia = len(pneumonia_files)
num_train_normal = int(num_normal * train_ratio)
num_train_pneumonia = int(num_pneumonia * train_ratio)
num_val_normal = int(num_normal * val_ratio)
num_val_pneumonia = int(num_pneumonia * val_ratio)
num_test_normal = int(num_normal * test_ratio)
num_test_pneumonia = int(num_pneumonia * test_ratio)

# Copy the image files to the output directories for each split
for i, file in enumerate(normal_files):
    if i < num_train_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "train", "0"))
    elif i < num_train_normal + num_val_normal:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "val", "0"))
    else:
        shutil.copy(os.path.join(data_dir, "NORMAL", file), os.path.join(output_dir, "test", "0"))
for i, file in enumerate(pneumonia_files):
    if i < num_train_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "train", "1"))
    elif i < num_train_pneumonia + num_val_pneumonia:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "val", "1"))
    else:
        shutil.copy(os.path.join(data_dir, "PNEUMONIA", file), os.path.join(output_dir, "test", "1"))

# %%
from PIL import Image
import os

# Set the path to the directory containing the images
directory = '/content/FinalDatasetTVT4/'

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
            # Open the image and convert it to RGB format
            img = Image.open(os.path.join(root, filename)).convert('RGB')
            
            # Save the image back to the same file
            img.save(os.path.join(root, filename))

# %%
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB2
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.layers import GlobalAveragePooling2D
from sklearn.metrics import precision_recall_curve
import seaborn as sns

# %%
# !pip install efficientnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from efficientnet) (0.19.3)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.8.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (2023.3.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (3.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (23.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet) (8.4.0)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %% [markdown]
# ## Imp1

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from efficientnet.tfkeras import EfficientNetB2
import numpy as np
from sklearn.metrics import roc_auc_score, recall_score, f1_score, precision_score

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=30,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/train',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/val',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/test',
    target_size=(128, 128),
    batch_size=1174,
    class_mode='binary')

# separate data and labels for training set
x_train, y_train = train_generator.next()

# separate data and labels for validation set
x_val, y_val = val_generator.next()

# separate data and labels for test set
x_test, y_test = test_generator.next()

# load pre-trained model
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# add new layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# freeze pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# class_labels = np.unique(y_train)
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train),
                                        y = y_train                                                    
                                    )
class_weights = dict(zip(np.unique(y_train), class_weights))

# define callbacks
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# save the model weights after each epoch if the validation loss decreased
checkpoint = ModelCheckpoint('best_model.h5', 
                             save_best_only=True, 
                             save_weights_only=True,
                             monitor='val_loss', 
                             mode='min', verbose=1)

# reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=10, 
                              min_lr=0.0001, verbose=1)

# stop training if the validation loss doesn't improve for 30 consecutive epochs
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# train the model
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=30,
                    batch_size=128,
                    callbacks=[checkpoint, reduce_lr, early_stop],
                    class_weight=class_weights
                    )

# evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, batch_size=128)

print('Test loss:', loss)
print('Test accuracy:', accuracy)

# evaluate the model on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)
auc_score = roc_auc_score(y_test, y_pred)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)

print('Test AUC:', auc_score)
print('Test Recall:', recall)
print('Test F1-score:', f1)
print('Test Precision:', precision)

# plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('A5.pdf')
plt.show()

# plot PR curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.savefig('A4.pdf')
plt.show()

# plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.savefig('A3.pdf')
plt.show()

# plot accuracy and loss curves for training and validation sets
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('A2.pdf')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('A1.pdf')
plt.show()

model.save('my_model.h5')
# Out:
# Found 3512 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.
# Found 1174 images belonging to 2 classes.
# Epoch 1/30
# 1/1 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.5312
# Epoch 1: val_loss improved from inf to 0.68482, saving model to best_model.h5
# 1/1 [==============================] - 10s 10s/step - loss: 0.7090 - accuracy: 0.5312 - val_loss: 0.6848 - val_accuracy: 0.5547 - lr: 0.0010
# Epoch 2/30
# 1/1 [==============================] - ETA: 0s - loss: 0.6396 - accuracy: 0.6641
# Epoch 2: val_loss improved from 0.68482 to 0.65309, saving model to best_model.h5
# 1/1 [==============================] - 1s 936ms/step - loss: 0.6396 - accuracy: 0.6641 - val_loss: 0.6531 - val_accuracy: 0.6641 - lr: 0.0010
# Epoch 3/30
# 1/1 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.6797
# Epoch 3: val_loss improved from 0.65309 to 0.60060, saving model to best_model.h5
# 1/1 [==============================] - 1s 925ms/step - loss: 0.6048 - accuracy: 0.6797 - val_loss: 0.6006 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 4/30
# 1/1 [==============================] - ETA: 0s - loss: 0.5511 - accuracy: 0.7344
# Epoch 4: val_loss improved from 0.60060 to 0.55703, saving model to best_model.h5
# 1/1 [==============================] - 1s 794ms/step - loss: 0.5511 - accuracy: 0.7344 - val_loss: 0.5570 - val_accuracy: 0.7734 - lr: 0.0010
# Epoch 5/30
# 1/1 [==============================] - ETA: 0s - loss: 0.5095 - accuracy: 0.7969
# Epoch 5: val_loss improved from 0.55703 to 0.50359, saving model to best_model.h5
# 1/1 [==============================] - 1s 752ms/step - loss: 0.5095 - accuracy: 0.7969 - val_loss: 0.5036 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 6/30
# 1/1 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8438
# Epoch 6: val_loss improved from 0.50359 to 0.43875, saving model to best_model.h5
# 1/1 [==============================] - 1s 715ms/step - loss: 0.4508 - accuracy: 0.8438 - val_loss: 0.4388 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 7/30
# 1/1 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.8516
# Epoch 7: val_loss improved from 0.43875 to 0.37318, saving model to best_model.h5
# 1/1 [==============================] - 1s 775ms/step - loss: 0.3943 - accuracy: 0.8516 - val_loss: 0.3732 - val_accuracy: 0.8359 - lr: 0.0010
# Epoch 8/30
# 1/1 [==============================] - ETA: 0s - loss: 0.3733 - accuracy: 0.8750
# Epoch 8: val_loss improved from 0.37318 to 0.33000, saving model to best_model.h5
# 1/1 [==============================] - 1s 763ms/step - loss: 0.3733 - accuracy: 0.8750 - val_loss: 0.3300 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 9/30
# 1/1 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.9141
# Epoch 9: val_loss improved from 0.33000 to 0.32130, saving model to best_model.h5
# 1/1 [==============================] - 1s 766ms/step - loss: 0.3195 - accuracy: 0.9141 - val_loss: 0.3213 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 10/30
# 1/1 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.8984
# Epoch 10: val_loss improved from 0.32130 to 0.31996, saving model to best_model.h5
# 1/1 [==============================] - 1s 748ms/step - loss: 0.3106 - accuracy: 0.8984 - val_loss: 0.3200 - val_accuracy: 0.8359 - lr: 0.0010
# Epoch 11/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.9062
# Epoch 11: val_loss improved from 0.31996 to 0.30368, saving model to best_model.h5
# 1/1 [==============================] - 1s 725ms/step - loss: 0.2921 - accuracy: 0.9062 - val_loss: 0.3037 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 12/30
# 1/1 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8516
# Epoch 12: val_loss improved from 0.30368 to 0.29341, saving model to best_model.h5
# 1/1 [==============================] - 1s 763ms/step - loss: 0.3005 - accuracy: 0.8516 - val_loss: 0.2934 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 13/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2993 - accuracy: 0.8672
# Epoch 13: val_loss did not improve from 0.29341
# 1/1 [==============================] - 0s 251ms/step - loss: 0.2993 - accuracy: 0.8672 - val_loss: 0.2967 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 14/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.8984
# Epoch 14: val_loss did not improve from 0.29341
# 1/1 [==============================] - 0s 285ms/step - loss: 0.2217 - accuracy: 0.8984 - val_loss: 0.2970 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 15/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.8906
# Epoch 15: val_loss improved from 0.29341 to 0.28606, saving model to best_model.h5
# 1/1 [==============================] - 1s 753ms/step - loss: 0.2479 - accuracy: 0.8906 - val_loss: 0.2861 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 16/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.9062
# Epoch 16: val_loss improved from 0.28606 to 0.26881, saving model to best_model.h5
# 1/1 [==============================] - 1s 759ms/step - loss: 0.2534 - accuracy: 0.9062 - val_loss: 0.2688 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 17/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2651 - accuracy: 0.8984
# Epoch 17: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 255ms/step - loss: 0.2651 - accuracy: 0.8984 - val_loss: 0.2770 - val_accuracy: 0.8672 - lr: 0.0010
# Epoch 18/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.9297
# Epoch 18: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 249ms/step - loss: 0.1838 - accuracy: 0.9297 - val_loss: 0.2863 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 19/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9297
# Epoch 19: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 289ms/step - loss: 0.2162 - accuracy: 0.9297 - val_loss: 0.2823 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 20/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.8984
# Epoch 20: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1943 - accuracy: 0.8984 - val_loss: 0.2897 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 21/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9141
# Epoch 21: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 272ms/step - loss: 0.1995 - accuracy: 0.9141 - val_loss: 0.2955 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 22/30
# 1/1 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.8828
# Epoch 22: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 301ms/step - loss: 0.2218 - accuracy: 0.8828 - val_loss: 0.2969 - val_accuracy: 0.8672 - lr: 0.0010
# Epoch 23/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9688
# Epoch 23: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 270ms/step - loss: 0.1524 - accuracy: 0.9688 - val_loss: 0.2989 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 24/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9219
# Epoch 24: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 274ms/step - loss: 0.1668 - accuracy: 0.9219 - val_loss: 0.2786 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 25/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9609
# Epoch 25: val_loss did not improve from 0.26881
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1382 - accuracy: 0.9609 - val_loss: 0.2853 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 26/30
# 1/1 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9375
# Epoch 26: val_loss did not improve from 0.26881
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1/1 [==============================] - 0s 297ms/step - loss: 0.1314 - accuracy: 0.9375 - val_loss: 0.3044 - val_accuracy: 0.8594 - lr: 0.0010
# 10/10 [==============================] - 3s 102ms/step - loss: 0.2955 - accuracy: 0.8765
# Test loss: 0.2954768240451813
# Test accuracy: 0.8764906525611877
# 37/37 [==============================] - 3s 30ms/step
# Test AUC: 0.9499426908834421
# Test Recall: 0.8691588785046729
# Test F1-score: 0.9112063686466625
# Test Precision: 0.9575289575289575

# %% [markdown]
# ## Imp2

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from efficientnet.tfkeras import EfficientNetB2
import numpy as np
from sklearn.metrics import roc_auc_score, recall_score, f1_score, precision_score

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=30,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/train',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/val',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/test',
    target_size=(128, 128),
    batch_size=1174,
    class_mode='binary')

# separate data and labels for training set
x_train, y_train = train_generator.next()

# separate data and labels for validation set
x_val, y_val = val_generator.next()

# separate data and labels for test set
x_test, y_test = test_generator.next()

# load pre-trained model
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# add new layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# freeze pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# class_labels = np.unique(y_train)
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train),
                                        y = y_train                                                    
                                    )
class_weights = dict(zip(np.unique(y_train), class_weights))

# define callbacks
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# save the model weights after each epoch if the validation loss decreased
checkpoint = ModelCheckpoint('best_model.h5', 
                             save_best_only=True, 
                             save_weights_only=True,
                             monitor='val_loss', 
                             mode='min', verbose=1)

# reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=15, 
                              min_lr=0.0001, verbose=1)

# stop training if the validation loss doesn't improve for 30 consecutive epochs
early_stop = EarlyStopping(monitor='val_loss', patience=20)

# compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# train the model
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=50,
                    batch_size=128,
                    callbacks=[checkpoint, reduce_lr, early_stop],
                    class_weight=class_weights
                    )

# evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, batch_size=1174)

print('Test loss:', loss)
print('Test accuracy:', accuracy)

# evaluate the model on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)
auc_score = roc_auc_score(y_test, y_pred)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)

print('Test AUC:', auc_score)
print('Test Recall:', recall)
print('Test F1-score:', f1)
print('Test Precision:', precision)

# plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('A5.pdf')
plt.show()

# plot PR curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.savefig('A4.pdf')
plt.show()

# plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.savefig('A3.pdf')
plt.show()

# plot accuracy and loss curves for training and validation sets
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('A2.pdf')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('A1.pdf')
plt.show()

model.save('my_model.h5')
# Out:
# Found 3512 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.
# Found 1174 images belonging to 2 classes.
# Epoch 1/50
# 1/1 [==============================] - ETA: 0s - loss: 0.7229 - accuracy: 0.6094
# Epoch 1: val_loss improved from inf to 0.63159, saving model to best_model.h5
# 1/1 [==============================] - 10s 10s/step - loss: 0.7229 - accuracy: 0.6094 - val_loss: 0.6316 - val_accuracy: 0.6953 - lr: 0.0010
# Epoch 2/50
# 1/1 [==============================] - ETA: 0s - loss: 0.6418 - accuracy: 0.6094
# Epoch 2: val_loss improved from 0.63159 to 0.57197, saving model to best_model.h5
# 1/1 [==============================] - 1s 894ms/step - loss: 0.6418 - accuracy: 0.6094 - val_loss: 0.5720 - val_accuracy: 0.8359 - lr: 0.0010
# Epoch 3/50
# 1/1 [==============================] - ETA: 0s - loss: 0.5372 - accuracy: 0.7188
# Epoch 3: val_loss improved from 0.57197 to 0.49042, saving model to best_model.h5
# 1/1 [==============================] - 1s 771ms/step - loss: 0.5372 - accuracy: 0.7188 - val_loss: 0.4904 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 4/50
# 1/1 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.8047
# Epoch 4: val_loss improved from 0.49042 to 0.41748, saving model to best_model.h5
# 1/1 [==============================] - 1s 732ms/step - loss: 0.4914 - accuracy: 0.8047 - val_loss: 0.4175 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 5/50
# 1/1 [==============================] - ETA: 0s - loss: 0.4552 - accuracy: 0.8438
# Epoch 5: val_loss improved from 0.41748 to 0.36052, saving model to best_model.h5
# 1/1 [==============================] - 1s 713ms/step - loss: 0.4552 - accuracy: 0.8438 - val_loss: 0.3605 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 6/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3860 - accuracy: 0.8828
# Epoch 6: val_loss improved from 0.36052 to 0.31737, saving model to best_model.h5
# 1/1 [==============================] - 1s 710ms/step - loss: 0.3860 - accuracy: 0.8828 - val_loss: 0.3174 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 7/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.9141
# Epoch 7: val_loss improved from 0.31737 to 0.28020, saving model to best_model.h5
# 1/1 [==============================] - 1s 701ms/step - loss: 0.3305 - accuracy: 0.9141 - val_loss: 0.2802 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 8/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.9062
# Epoch 8: val_loss improved from 0.28020 to 0.25423, saving model to best_model.h5
# 1/1 [==============================] - 1s 747ms/step - loss: 0.3412 - accuracy: 0.9062 - val_loss: 0.2542 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 9/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3010 - accuracy: 0.8672
# Epoch 9: val_loss improved from 0.25423 to 0.23481, saving model to best_model.h5
# 1/1 [==============================] - 1s 728ms/step - loss: 0.3010 - accuracy: 0.8672 - val_loss: 0.2348 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 10/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8828
# Epoch 10: val_loss improved from 0.23481 to 0.22223, saving model to best_model.h5
# 1/1 [==============================] - 1s 742ms/step - loss: 0.2784 - accuracy: 0.8828 - val_loss: 0.2222 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 11/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.8906
# Epoch 11: val_loss improved from 0.22223 to 0.21461, saving model to best_model.h5
# 1/1 [==============================] - 1s 721ms/step - loss: 0.2755 - accuracy: 0.8906 - val_loss: 0.2146 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 12/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8984
# Epoch 12: val_loss improved from 0.21461 to 0.20948, saving model to best_model.h5
# 1/1 [==============================] - 1s 703ms/step - loss: 0.2807 - accuracy: 0.8984 - val_loss: 0.2095 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 13/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9062
# Epoch 13: val_loss improved from 0.20948 to 0.19841, saving model to best_model.h5
# 1/1 [==============================] - 1s 719ms/step - loss: 0.2064 - accuracy: 0.9062 - val_loss: 0.1984 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 14/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.8516
# Epoch 14: val_loss improved from 0.19841 to 0.19200, saving model to best_model.h5
# 1/1 [==============================] - 1s 702ms/step - loss: 0.3057 - accuracy: 0.8516 - val_loss: 0.1920 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 15/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9453
# Epoch 15: val_loss improved from 0.19200 to 0.18996, saving model to best_model.h5
# 1/1 [==============================] - 1s 726ms/step - loss: 0.1845 - accuracy: 0.9453 - val_loss: 0.1900 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 16/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9375
# Epoch 16: val_loss improved from 0.18996 to 0.18822, saving model to best_model.h5
# 1/1 [==============================] - 1s 735ms/step - loss: 0.1717 - accuracy: 0.9375 - val_loss: 0.1882 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 17/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9375
# Epoch 17: val_loss improved from 0.18822 to 0.18809, saving model to best_model.h5
# 1/1 [==============================] - 1s 889ms/step - loss: 0.1576 - accuracy: 0.9375 - val_loss: 0.1881 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 18/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9062
# Epoch 18: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 308ms/step - loss: 0.2242 - accuracy: 0.9062 - val_loss: 0.1891 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 19/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2139 - accuracy: 0.9609
# Epoch 19: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 304ms/step - loss: 0.2139 - accuracy: 0.9609 - val_loss: 0.1906 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 20/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9297
# Epoch 20: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1455 - accuracy: 0.9297 - val_loss: 0.1925 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 21/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9531
# Epoch 21: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1620 - accuracy: 0.9531 - val_loss: 0.1955 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 22/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9375
# Epoch 22: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 299ms/step - loss: 0.1540 - accuracy: 0.9375 - val_loss: 0.1978 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 23/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9375
# Epoch 23: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1485 - accuracy: 0.9375 - val_loss: 0.2001 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 24/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9453
# Epoch 24: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 249ms/step - loss: 0.1080 - accuracy: 0.9453 - val_loss: 0.2007 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 25/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9531
# Epoch 25: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 251ms/step - loss: 0.1019 - accuracy: 0.9531 - val_loss: 0.2029 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 26/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9375
# Epoch 26: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 287ms/step - loss: 0.2161 - accuracy: 0.9375 - val_loss: 0.2081 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 27/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9766
# Epoch 27: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0629 - accuracy: 0.9766 - val_loss: 0.2143 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 28/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9688
# Epoch 28: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 272ms/step - loss: 0.1054 - accuracy: 0.9688 - val_loss: 0.2174 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 29/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9766
# Epoch 29: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0891 - accuracy: 0.9766 - val_loss: 0.2198 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 30/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0710 - accuracy: 0.9766
# Epoch 30: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0710 - accuracy: 0.9766 - val_loss: 0.2222 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 31/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9766
# Epoch 31: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0721 - accuracy: 0.9766 - val_loss: 0.2259 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 32/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9844
# Epoch 32: val_loss did not improve from 0.18809
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0545 - accuracy: 0.9844 - val_loss: 0.2292 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 33/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9766
# Epoch 33: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0831 - accuracy: 0.9766 - val_loss: 0.2293 - val_accuracy: 0.9062 - lr: 2.0000e-04
# Epoch 34/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9922
# Epoch 34: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0668 - accuracy: 0.9922 - val_loss: 0.2293 - val_accuracy: 0.9062 - lr: 2.0000e-04
# Epoch 35/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9609
# Epoch 35: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0821 - accuracy: 0.9609 - val_loss: 0.2295 - val_accuracy: 0.9062 - lr: 2.0000e-04
# Epoch 36/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9844
# Epoch 36: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0557 - accuracy: 0.9844 - val_loss: 0.2301 - val_accuracy: 0.9062 - lr: 2.0000e-04
# Epoch 37/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9922
# Epoch 37: val_loss did not improve from 0.18809
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0731 - accuracy: 0.9922 - val_loss: 0.2310 - val_accuracy: 0.9062 - lr: 2.0000e-04
# 1/1 [==============================] - 3s 3s/step - loss: 0.2670 - accuracy: 0.8969
# Test loss: 0.2669734060764313
# Test accuracy: 0.8969335556030273
# 37/37 [==============================] - 3s 30ms/step
# Test AUC: 0.957561864456592
# Test Recall: 0.927570093457944
# Test F1-score: 0.9291983616149796
# Test Precision: 0.9308323563892146

# %% [markdown]
# ## Imp3

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from efficientnet.tfkeras import EfficientNetB2
import numpy as np
from sklearn.metrics import roc_auc_score, recall_score, f1_score, precision_score

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=30,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/train',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/val',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/test',
    target_size=(128, 128),
    batch_size=1174,
    class_mode='binary')

# separate data and labels for training set
x_train, y_train = train_generator.next()

# separate data and labels for validation set
x_val, y_val = val_generator.next()

# separate data and labels for test set
x_test, y_test = test_generator.next()

# load pre-trained model
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# add new layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# freeze pre-trained layers
for layer in base_model.layers:
    layer.trainable = True

import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# class_labels = np.unique(y_train)
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train),
                                        y = y_train                                                    
                                    )
class_weights = dict(zip(np.unique(y_train), class_weights))

# define callbacks
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# save the model weights after each epoch if the validation loss decreased
checkpoint = ModelCheckpoint('best_model.h5', 
                             save_best_only=True, 
                             save_weights_only=True,
                             monitor='val_loss', 
                             mode='min', verbose=1)

# reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=10, 
                              min_lr=0.0001, verbose=1)

# stop training if the validation loss doesn't improve for 30 consecutive epochs
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# train the model
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=11,
                    batch_size=128,
                    callbacks=[checkpoint, reduce_lr, early_stop],
                    class_weight=class_weights
                    )

# evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, batch_size=1174)

print('Test loss:', loss)
print('Test accuracy:', accuracy)

# evaluate the model on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)
auc_score = roc_auc_score(y_test, y_pred)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)

print('Test AUC:', auc_score)
print('Test Recall:', recall)
print('Test F1-score:', f1)
print('Test Precision:', precision)

# plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('A5.pdf')
plt.show()

# plot PR curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.savefig('A4.pdf')
plt.show()

# plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.savefig('A3.pdf')
plt.show()

# plot accuracy and loss curves for training and validation sets
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('A2.pdf')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('A1.pdf')
plt.show()

model.save('my_model.h5')
# Out:
# Found 3512 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.
# Found 1174 images belonging to 2 classes.
# Epoch 1/11
# 1/1 [==============================] - ETA: 0s - loss: 0.7354 - accuracy: 0.2734
# Epoch 1: val_loss improved from inf to 0.73232, saving model to best_model.h5
# 1/1 [==============================] - 60s 60s/step - loss: 0.7354 - accuracy: 0.2734 - val_loss: 0.7323 - val_accuracy: 0.4141 - lr: 0.0010
# Epoch 2/11
# 1/1 [==============================] - ETA: 0s - loss: 0.5534 - accuracy: 0.6484
# Epoch 2: val_loss improved from 0.73232 to 0.67491, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.5534 - accuracy: 0.6484 - val_loss: 0.6749 - val_accuracy: 0.5469 - lr: 0.0010
# Epoch 3/11
# 1/1 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.8281
# Epoch 3: val_loss improved from 0.67491 to 0.61348, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.4207 - accuracy: 0.8281 - val_loss: 0.6135 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 4/11
# 1/1 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.9609
# Epoch 4: val_loss improved from 0.61348 to 0.54535, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.2953 - accuracy: 0.9609 - val_loss: 0.5454 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 5/11
# 1/1 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9844
# Epoch 5: val_loss improved from 0.54535 to 0.46608, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.2253 - accuracy: 0.9844 - val_loss: 0.4661 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 6/11
# 1/1 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9922
# Epoch 6: val_loss improved from 0.46608 to 0.37930, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.1686 - accuracy: 0.9922 - val_loss: 0.3793 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 7/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9922
# Epoch 7: val_loss improved from 0.37930 to 0.29881, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.0981 - accuracy: 0.9922 - val_loss: 0.2988 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 8/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 1.0000
# Epoch 8: val_loss improved from 0.29881 to 0.24523, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 9/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.24523 to 0.22265, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 10/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 0.22265
# 1/1 [==============================] - 1s 601ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 11/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.22265
# 1/1 [==============================] - 1s 602ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9219 - lr: 0.0010
# 1/1 [==============================] - 3s 3s/step - loss: 0.3549 - accuracy: 0.8944
# Test loss: 0.35489439964294434
# Test accuracy: 0.8943781852722168
# 37/37 [==============================] - 3s 30ms/step
# Test AUC: 0.9510190736495621
# Test Recall: 0.9357476635514018
# Test F1-score: 0.9281575898030128
# Test Precision: 0.9206896551724137

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from efficientnet.tfkeras import EfficientNetB2
import numpy as np
from sklearn.metrics import roc_auc_score, recall_score, f1_score, precision_score

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=30,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/train',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/val',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/test',
    target_size=(128, 128),
    batch_size=1174,
    class_mode='binary')

# separate data and labels for training set
x_train, y_train = train_generator.next()

# separate data and labels for validation set
x_val, y_val = val_generator.next()

# separate data and labels for test set
x_test, y_test = test_generator.next()

# load pre-trained model
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# add new layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# freeze pre-trained layers
for layer in base_model.layers:
    layer.trainable = True

import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# class_labels = np.unique(y_train)
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train),
                                        y = y_train                                                    
                                    )
class_weights = dict(zip(np.unique(y_train), class_weights))

# define callbacks
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# save the model weights after each epoch if the validation loss decreased
checkpoint = ModelCheckpoint('best_model.h5', 
                             save_best_only=True, 
                             save_weights_only=True,
                             monitor='val_loss', 
                             mode='min', verbose=1)

# reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=10, 
                              min_lr=0.0001, verbose=1)

# stop training if the validation loss doesn't improve for 30 consecutive epochs
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# train the model
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=11,
                    batch_size=128,
                    callbacks=[checkpoint, reduce_lr, early_stop],
                    class_weight=class_weights
                    )

# evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, batch_size=1174)

print('Test loss:', loss)
print('Test accuracy:', accuracy)

# evaluate the model on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)
auc_score = roc_auc_score(y_test, y_pred)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)

print('Test AUC:', auc_score)
print('Test Recall:', recall)
print('Test F1-score:', f1)
print('Test Precision:', precision)

# plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('A5.pdf')
plt.show()

# plot PR curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.savefig('A4.pdf')
plt.show()

# plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.savefig('A3.pdf')
plt.show()

# plot accuracy and loss curves for training and validation sets
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('A2.pdf')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('A1.pdf')
plt.show()

model.save('my_model.h5')
# Out:
# Found 3512 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.
# Found 1174 images belonging to 2 classes.
# Epoch 1/11
# 1/1 [==============================] - ETA: 0s - loss: 0.7354 - accuracy: 0.2734
# Epoch 1: val_loss improved from inf to 0.73232, saving model to best_model.h5
# 1/1 [==============================] - 60s 60s/step - loss: 0.7354 - accuracy: 0.2734 - val_loss: 0.7323 - val_accuracy: 0.4141 - lr: 0.0010
# Epoch 2/11
# 1/1 [==============================] - ETA: 0s - loss: 0.5534 - accuracy: 0.6484
# Epoch 2: val_loss improved from 0.73232 to 0.67491, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.5534 - accuracy: 0.6484 - val_loss: 0.6749 - val_accuracy: 0.5469 - lr: 0.0010
# Epoch 3/11
# 1/1 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.8281
# Epoch 3: val_loss improved from 0.67491 to 0.61348, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.4207 - accuracy: 0.8281 - val_loss: 0.6135 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 4/11
# 1/1 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.9609
# Epoch 4: val_loss improved from 0.61348 to 0.54535, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.2953 - accuracy: 0.9609 - val_loss: 0.5454 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 5/11
# 1/1 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9844
# Epoch 5: val_loss improved from 0.54535 to 0.46608, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.2253 - accuracy: 0.9844 - val_loss: 0.4661 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 6/11
# 1/1 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9922
# Epoch 6: val_loss improved from 0.46608 to 0.37930, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.1686 - accuracy: 0.9922 - val_loss: 0.3793 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 7/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9922
# Epoch 7: val_loss improved from 0.37930 to 0.29881, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.0981 - accuracy: 0.9922 - val_loss: 0.2988 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 8/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 1.0000
# Epoch 8: val_loss improved from 0.29881 to 0.24523, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 9/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.24523 to 0.22265, saving model to best_model.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 10/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 0.22265
# 1/1 [==============================] - 1s 601ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 11/11
# 1/1 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.22265
# 1/1 [==============================] - 1s 602ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9219 - lr: 0.0010
# 1/1 [==============================] - 3s 3s/step - loss: 0.3549 - accuracy: 0.8944
# Test loss: 0.35489439964294434
# Test accuracy: 0.8943781852722168
# 37/37 [==============================] - 3s 30ms/step
# Test AUC: 0.9510190736495621
# Test Recall: 0.9357476635514018
# Test F1-score: 0.9281575898030128
# Test Precision: 0.9206896551724137

# %% [markdown]
# ## Imp4

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from efficientnet.tfkeras import EfficientNetB2
import numpy as np
from sklearn.metrics import roc_auc_score, recall_score, f1_score, precision_score

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rotation_range=30,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/train',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/val',
    target_size=(128, 128),
    batch_size=128,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    '/content/FinalDatasetTVT2/test',
    target_size=(128, 128),
    batch_size=1174,
    class_mode='binary')

# separate data and labels for training set
x_train, y_train = train_generator.next()

# separate data and labels for validation set
x_val, y_val = val_generator.next()

# separate data and labels for test set
x_test, y_test = test_generator.next()

# load pre-trained model
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# add new layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# freeze pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# class_labels = np.unique(y_train)
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train),
                                        y = y_train                                                    
                                    )
class_weights = dict(zip(np.unique(y_train), class_weights))

# define callbacks
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# save the model weights after each epoch if the validation loss decreased
checkpoint = ModelCheckpoint('best_model.h5', 
                             save_best_only=True, 
                             save_weights_only=True,
                             monitor='val_loss', 
                             mode='min', verbose=1)

# reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=15, 
                              min_lr=0.0001, verbose=1)

# stop training if the validation loss doesn't improve for 30 consecutive epochs
early_stop = EarlyStopping(monitor='val_loss', patience=20)

# compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# train the model
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=50,
                    batch_size=128,
                    callbacks=[checkpoint, reduce_lr, early_stop],
                    class_weight=class_weights
                    )

# evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, batch_size=1174)

print('Test loss:', loss)
print('Test accuracy:', accuracy)

# evaluate the model on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)
auc_score = roc_auc_score(y_test, y_pred)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)

print('Test AUC:', auc_score)
print('Test Recall:', recall)
print('Test F1-score:', f1)
print('Test Precision:', precision)

# plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('A5.pdf')
plt.show()

# plot PR curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.savefig('A4.pdf')
plt.show()

# plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.savefig('A3.pdf')
plt.show()

# plot accuracy and loss curves for training and validation sets
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('A2.pdf')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('A1.pdf')
plt.show()

model.save('my_model.h5')
# Out:
# Found 3512 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.
# Found 1174 images belonging to 2 classes.
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b2_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 31936256/31936256 [==============================] - 0s 0us/step
# Epoch 1/50
# 1/1 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.3594
# Epoch 1: val_loss improved from inf to 0.65851, saving model to best_model.h5
# 1/1 [==============================] - 19s 19s/step - loss: 0.7200 - accuracy: 0.3594 - val_loss: 0.6585 - val_accuracy: 0.6562 - lr: 0.0010
# Epoch 2/50
# 1/1 [==============================] - ETA: 0s - loss: 0.6577 - accuracy: 0.6328
# Epoch 2: val_loss improved from 0.65851 to 0.56593, saving model to best_model.h5
# 1/1 [==============================] - 1s 705ms/step - loss: 0.6577 - accuracy: 0.6328 - val_loss: 0.5659 - val_accuracy: 0.8672 - lr: 0.0010
# Epoch 3/50
# 1/1 [==============================] - ETA: 0s - loss: 0.5893 - accuracy: 0.8516
# Epoch 3: val_loss improved from 0.56593 to 0.51164, saving model to best_model.h5
# 1/1 [==============================] - 1s 696ms/step - loss: 0.5893 - accuracy: 0.8516 - val_loss: 0.5116 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 4/50
# 1/1 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.7734
# Epoch 4: val_loss improved from 0.51164 to 0.47135, saving model to best_model.h5
# 1/1 [==============================] - 1s 703ms/step - loss: 0.5526 - accuracy: 0.7734 - val_loss: 0.4714 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 5/50
# 1/1 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.8438
# Epoch 5: val_loss improved from 0.47135 to 0.44870, saving model to best_model.h5
# 1/1 [==============================] - 1s 801ms/step - loss: 0.4933 - accuracy: 0.8438 - val_loss: 0.4487 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 6/50
# 1/1 [==============================] - ETA: 0s - loss: 0.4946 - accuracy: 0.7734
# Epoch 6: val_loss improved from 0.44870 to 0.41829, saving model to best_model.h5
# 1/1 [==============================] - 1s 878ms/step - loss: 0.4946 - accuracy: 0.7734 - val_loss: 0.4183 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 7/50
# 1/1 [==============================] - ETA: 0s - loss: 0.4694 - accuracy: 0.7500
# Epoch 7: val_loss improved from 0.41829 to 0.36673, saving model to best_model.h5
# 1/1 [==============================] - 1s 867ms/step - loss: 0.4694 - accuracy: 0.7500 - val_loss: 0.3667 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 8/50
# 1/1 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.8125
# Epoch 8: val_loss improved from 0.36673 to 0.31514, saving model to best_model.h5
# 1/1 [==============================] - 1s 718ms/step - loss: 0.4461 - accuracy: 0.8125 - val_loss: 0.3151 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 9/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8359
# Epoch 9: val_loss improved from 0.31514 to 0.28647, saving model to best_model.h5
# 1/1 [==============================] - 1s 676ms/step - loss: 0.3957 - accuracy: 0.8359 - val_loss: 0.2865 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 10/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8672
# Epoch 10: val_loss improved from 0.28647 to 0.27265, saving model to best_model.h5
# 1/1 [==============================] - 1s 725ms/step - loss: 0.3661 - accuracy: 0.8672 - val_loss: 0.2727 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 11/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3283 - accuracy: 0.8750
# Epoch 11: val_loss improved from 0.27265 to 0.26095, saving model to best_model.h5
# 1/1 [==============================] - 1s 680ms/step - loss: 0.3283 - accuracy: 0.8750 - val_loss: 0.2610 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 12/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3568 - accuracy: 0.8516
# Epoch 12: val_loss improved from 0.26095 to 0.25383, saving model to best_model.h5
# 1/1 [==============================] - 1s 713ms/step - loss: 0.3568 - accuracy: 0.8516 - val_loss: 0.2538 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 13/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8672
# Epoch 13: val_loss improved from 0.25383 to 0.25002, saving model to best_model.h5
# 1/1 [==============================] - 1s 671ms/step - loss: 0.3384 - accuracy: 0.8672 - val_loss: 0.2500 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 14/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.9062
# Epoch 14: val_loss did not improve from 0.25002
# 1/1 [==============================] - 0s 252ms/step - loss: 0.2894 - accuracy: 0.9062 - val_loss: 0.2582 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 15/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.8828
# Epoch 15: val_loss did not improve from 0.25002
# 1/1 [==============================] - 0s 242ms/step - loss: 0.2437 - accuracy: 0.8828 - val_loss: 0.2566 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 16/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.8828
# Epoch 16: val_loss did not improve from 0.25002
# 1/1 [==============================] - 0s 240ms/step - loss: 0.2364 - accuracy: 0.8828 - val_loss: 0.2508 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 17/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.8906
# Epoch 17: val_loss improved from 0.25002 to 0.24307, saving model to best_model.h5
# 1/1 [==============================] - 1s 712ms/step - loss: 0.2790 - accuracy: 0.8906 - val_loss: 0.2431 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 18/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.8672
# Epoch 18: val_loss improved from 0.24307 to 0.24040, saving model to best_model.h5
# 1/1 [==============================] - 1s 724ms/step - loss: 0.2620 - accuracy: 0.8672 - val_loss: 0.2404 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 19/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9375
# Epoch 19: val_loss improved from 0.24040 to 0.23969, saving model to best_model.h5
# 1/1 [==============================] - 1s 695ms/step - loss: 0.2136 - accuracy: 0.9375 - val_loss: 0.2397 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 20/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2509 - accuracy: 0.9141
# Epoch 20: val_loss did not improve from 0.23969
# 1/1 [==============================] - 0s 252ms/step - loss: 0.2509 - accuracy: 0.9141 - val_loss: 0.2444 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 21/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.8828
# Epoch 21: val_loss did not improve from 0.23969
# 1/1 [==============================] - 0s 252ms/step - loss: 0.2742 - accuracy: 0.8828 - val_loss: 0.2532 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 22/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9062
# Epoch 22: val_loss did not improve from 0.23969
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1861 - accuracy: 0.9062 - val_loss: 0.2570 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 23/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9375
# Epoch 23: val_loss did not improve from 0.23969
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1630 - accuracy: 0.9375 - val_loss: 0.2459 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 24/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9219
# Epoch 24: val_loss improved from 0.23969 to 0.23718, saving model to best_model.h5
# 1/1 [==============================] - 1s 719ms/step - loss: 0.1700 - accuracy: 0.9219 - val_loss: 0.2372 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 25/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9375
# Epoch 25: val_loss improved from 0.23718 to 0.23532, saving model to best_model.h5
# 1/1 [==============================] - 1s 687ms/step - loss: 0.2186 - accuracy: 0.9375 - val_loss: 0.2353 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 26/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9531
# Epoch 26: val_loss improved from 0.23532 to 0.23501, saving model to best_model.h5
# 1/1 [==============================] - 1s 821ms/step - loss: 0.1510 - accuracy: 0.9531 - val_loss: 0.2350 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 27/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9531
# Epoch 27: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1446 - accuracy: 0.9531 - val_loss: 0.2395 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 28/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9453
# Epoch 28: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1925 - accuracy: 0.9453 - val_loss: 0.2436 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 29/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9453
# Epoch 29: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1570 - accuracy: 0.9453 - val_loss: 0.2394 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 30/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9297
# Epoch 30: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 262ms/step - loss: 0.1981 - accuracy: 0.9297 - val_loss: 0.2428 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 31/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9297
# Epoch 31: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1672 - accuracy: 0.9297 - val_loss: 0.2552 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 32/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9688
# Epoch 32: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 258ms/step - loss: 0.1128 - accuracy: 0.9688 - val_loss: 0.2584 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 33/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9297
# Epoch 33: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1150 - accuracy: 0.9297 - val_loss: 0.2509 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 34/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9297
# Epoch 34: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 276ms/step - loss: 0.1237 - accuracy: 0.9297 - val_loss: 0.2495 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 35/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9844
# Epoch 35: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0770 - accuracy: 0.9844 - val_loss: 0.2695 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 36/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9766
# Epoch 36: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1328 - accuracy: 0.9766 - val_loss: 0.2815 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 37/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9609
# Epoch 37: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 238ms/step - loss: 0.1299 - accuracy: 0.9609 - val_loss: 0.2713 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 38/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9375
# Epoch 38: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 238ms/step - loss: 0.1416 - accuracy: 0.9375 - val_loss: 0.2555 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 39/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9609
# Epoch 39: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0942 - accuracy: 0.9609 - val_loss: 0.2473 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 40/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9609
# Epoch 40: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1147 - accuracy: 0.9609 - val_loss: 0.2491 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 41/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9609
# Epoch 41: val_loss did not improve from 0.23501
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0976 - accuracy: 0.9609 - val_loss: 0.2601 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 42/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9141
# Epoch 42: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 241ms/step - loss: 0.1670 - accuracy: 0.9141 - val_loss: 0.2570 - val_accuracy: 0.8984 - lr: 2.0000e-04
# Epoch 43/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9141
# Epoch 43: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1469 - accuracy: 0.9141 - val_loss: 0.2502 - val_accuracy: 0.8984 - lr: 2.0000e-04
# Epoch 44/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9609
# Epoch 44: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1057 - accuracy: 0.9609 - val_loss: 0.2441 - val_accuracy: 0.9062 - lr: 2.0000e-04
# Epoch 45/50
# 1/1 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9453
# Epoch 45: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1080 - accuracy: 0.9453 - val_loss: 0.2407 - val_accuracy: 0.9141 - lr: 2.0000e-04
# Epoch 46/50
# 1/1 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9297
# Epoch 46: val_loss did not improve from 0.23501
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0997 - accuracy: 0.9297 - val_loss: 0.2408 - val_accuracy: 0.9062 - lr: 2.0000e-04
# 1/1 [==============================] - 10s 10s/step - loss: 0.2831 - accuracy: 0.8859
# Test loss: 0.2830770015716553
# Test accuracy: 0.8858603239059448
# 37/37 [==============================] - 5s 45ms/step
# Test AUC: 0.941647563627814
# Test Recall: 0.9112149532710281
# Test F1-score: 0.9208972845336482
# Test Precision: 0.9307875894988067

# %%
from sklearn.metrics import classification_report

# get predicted classes
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)

# create classification report
target_names = ['NORMAL', 'PNEUMONIA']
print(classification_report(y_test, y_pred_classes, target_names=target_names))
# Out:
# 37/37 [==============================] - 2s 43ms/step
#               precision    recall  f1-score   support
#
#       NORMAL       0.77      0.82      0.80       318
#    PNEUMONIA       0.93      0.91      0.92       856
#
#     accuracy                           0.89      1174
#    macro avg       0.85      0.86      0.86      1174
# weighted avg       0.89      0.89      0.89      1174
